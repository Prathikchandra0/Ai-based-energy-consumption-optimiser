# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathikchandra0/Ai-based-energy-consumption-optimiser/blob/main/embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
pairs =[
    ("i love dogs" , "i love cats")
]

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
for text1, text2 in pairs:
  emb1 = model.encode(text1)
  emb2 = model.encode(text2)

def cosine_similarity(vec1 , vec2):
  vec1 , vec2 = np.array(vec1), np.array(vec2)
  return float(np.dot(vec1,vec2))/(np.linalg.norm(vec1)*np.linalg.norm(vec2))

for text1, tect2 in pairs:
  sim = cosine_similarity(emb1 , emb2)
  print(f"similarity: {sim :.4f}" )
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# similarity: 0.7721
